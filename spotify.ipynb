# %% [markdown]
# # What makes a song chart and make money?
# ## Jacob Cuomo, Dylan Fox, and Ryan Tran, and Colby Luttrell

# %% [markdown]
# ### Data import and Cleanse

# %%
# Import appropriate libraries
import pandas as pd # loading in data
import numpy as np
import matplotlib.pyplot as plt # creating visualizations
import seaborn as sns # also for creating visualizations
import re # filtering out special characters using regex

# for multiple regression model
import statsmodels
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.feature_selection import RFECV
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
# Import dataset
spotify = pd.read_csv('spotify_dataset.csv')
spotify.head()
# Out:
#    Index  Highest Charting Position  Number of Times Charted  \
# 0      1                          1                        8
# 1      2                          2                        3
# 2      3                          1                       11
# 3      4                          3                        5
# 4      5                          5                        1
#
#   Week of Highest Charting                          Song Name     Streams  \
# 0   2021-07-23--2021-07-30                            Beggin'  48,633,449
# 1   2021-07-23--2021-07-30          STAY (with Justin Bieber)  47,248,719
# 2   2021-06-25--2021-07-02                           good 4 u  40,162,559
# 3   2021-07-02--2021-07-09                         Bad Habits  37,799,456
# 4   2021-07-23--2021-07-30  INDUSTRY BABY (feat. Jack Harlow)  33,948,454
#
#            Artist Artist Followers                 Song ID  \
# 0        Måneskin          3377762  3Wrjm47oTz2sjIgck11l5e
# 1   The Kid LAROI          2230022  5HCyWlXZPP0y6Gqq8TgA20
# 2  Olivia Rodrigo          6266514  4ZtFanR9U6ndgddUvNcjcG
# 3      Ed Sheeran         83293380  6PQ88X9TkUIAUIZJHW2upE
# 4       Lil Nas X          5473565  27NovPIUIRrOZoCHxABJwK
#
#                                     Genre  ... Danceability Energy Loudness  \
# 0  ['indie rock italiano', 'italian pop']  ...        0.714    0.8   -4.808
# 1                  ['australian hip hop']  ...        0.591  0.764   -5.484
# 2                                 ['pop']  ...        0.563  0.664   -5.044
# 3                       ['pop', 'uk pop']  ...        0.808  0.897   -3.712
# 4           ['lgbtq+ hip hop', 'pop rap']  ...        0.736  0.704   -7.409
#
#   Speechiness Acousticness Liveness    Tempo Duration (ms) Valence  Chord
# 0      0.0504        0.127    0.359  134.002        211560   0.589      B
# 1      0.0483       0.0383    0.103  169.928        141806   0.478  C#/Db
# 2       0.154        0.335   0.0849  166.928        178147   0.688      A
# 3      0.0348       0.0469    0.364  126.026        231041   0.591      B
# 4      0.0615       0.0203   0.0501  149.995        212000   0.894  D#/Eb
#
# [5 rows x 23 columns]

# %%
# Quickly look over variables in the user file
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1556 entries, 0 to 1555
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Index                      1556 non-null   int64
#  1   Highest Charting Position  1556 non-null   int64
#  2   Number of Times Charted    1556 non-null   int64
#  3   Week of Highest Charting   1556 non-null   object
#  4   Song Name                  1556 non-null   object
#  5   Streams                    1556 non-null   object
#  6   Artist                     1556 non-null   object
#  7   Artist Followers           1556 non-null   object
#  8   Song ID                    1556 non-null   object
#  9   Genre                      1556 non-null   object
#  10  Release Date               1556 non-null   object
#  11  Weeks Charted              1556 non-null   object
#  12  Popularity                 1556 non-null   object
#  13  Danceability               1556 non-null   object
#  14  Energy                     1556 non-null   object
#  15  Loudness                   1556 non-null   object
#  16  Speechiness                1556 non-null   object
#  17  Acousticness               1556 non-null   object
#  18  Liveness                   1556 non-null   object
#  19  Tempo                      1556 non-null   object
#  20  Duration (ms)              1556 non-null   object
#  21  Valence                    1556 non-null   object
#  22  Chord                      1556 non-null   object
# dtypes: int64(3), object(20)
# memory usage: 279.7+ KB

# %%
# Check if there are any missing values?
print("Are there any missing values?:")
print(spotify.isnull().values.any())
# Out:
# Are there any missing values?:
# False

# %%
# It may seem that there are not any missing values but if you take a closer look...
count = 0

blanks = spotify.loc[spotify['Song ID'] == ' ']
count = len(blanks)
print("There are", count, "missing values.")

#Where are the missing values?
spotify.loc[spotify['Song ID'] == ' ']
# Out:
# There are 11 missing values.
#       Index  Highest Charting Position  Number of Times Charted  \
# 35       36                         36                        1
# 163     164                          5                       39
# 464     465                        118                        1
# 530     531                         20                        5
# 636     637                         22                        6
# 654     655                         73                        1
# 750     751                         19                       20
# 784     785                         76                       14
# 876     877                        164                        4
# 1140   1141                        131                        1
# 1538   1539                        176                        1
#
#      Week of Highest Charting  \
# 35     2021-07-23--2021-07-30
# 163    2020-10-30--2020-11-06
# 464    2021-03-26--2021-04-02
# 530    2021-01-15--2021-01-22
# 636    2020-12-18--2020-12-25
# 654    2020-12-18--2020-12-25
# 750    2020-07-31--2020-08-07
# 784    2020-09-04--2020-09-11
# 876    2020-09-18--2020-09-25
# 1140   2020-05-29--2020-06-05
# 1538   2020-01-03--2020-01-10
#
#                                               Song Name     Streams  \
# 35            NOT SOBER (feat. Polo G & Stunna Gambino)  11,869,336
# 163                                               34+35   5,453,159
# 464                               Richer (feat. Polo G)   6,292,362
# 530   34+35 Remix (feat. Doja Cat, Megan Thee Stalli...   6,162,453
# 636          Driving Home for Christmas - 2019 Remaster   8,804,531
# 654         Thank God It's Christmas - Non-Album Single  10,509,961
# 750   Agua (with J Balvin) - Music From "Sponge On T...   5,358,940
# 784   Lean (feat. Towy, Osquel, Beltito & Sammy & Fa...   4,739,241
# 876                                              +Linda   4,964,708
# 1140                                     In meinem Benz   5,494,500
# 1538  fuck, i'm lonely (with Anne-Marie) - from “13 ...   4,856,458
#
#                             Artist Artist Followers Song ID Genre  ...  \
# 35                   The Kid LAROI                                 ...
# 163                  Ariana Grande                                 ...
# 464                       Rod Wave                                 ...
# 530                  Ariana Grande                                 ...
# 636                      Chris Rea                                 ...
# 654                          Queen                                 ...
# 750                          Tainy                                 ...
# 784          Super Yei, Jone Quest                                 ...
# 876                          Dalex                                 ...
# 1140  AK AUSSERKONTROLLE, Bonez MC                                 ...
# 1538                          Lauv                                 ...
#
#      Danceability Energy Loudness Speechiness Acousticness Liveness Tempo  \
# 35
# 163
# 464
# 530
# 636
# 654
# 750
# 784
# 876
# 1140
# 1538
#
#      Duration (ms) Valence Chord
# 35
# 163
# 464
# 530
# 636
# 654
# 750
# 784
# 876
# 1140
# 1538
#
# [11 rows x 23 columns]

# %% [markdown]
# ##### User Visualizations

# %%
# Analyze the number of times an artists shows up in the dataset, does being a certain artist increase chances of a popular
# hit song?
spotify['Artist'].value_counts()
# Out:
# Taylor Swift            52
# Justin Bieber           32
# Lil Uzi Vert            32
# Juice WRLD              30
# Pop Smoke               29
#                         ..
# Kane Brown               1
# Cordae                   1
# Headie One               1
# KAROL G, Nicki Minaj     1
# Drake, WizKid, Kyla      1
# Name: Artist, Length: 716, dtype: int64

# %%
# Create a visualization for the number of songs for each artist
sns.set_theme(style="whitegrid") # from Data Science 1500
sns.set(rc={'figure.figsize':(9,6)})
sns.countplot(x="Artist", data=spotify, capsize=.1, palette="rocket", 
             order=spotify.Artist.value_counts().iloc[:10].index)

plt.xticks(rotation = 70) # rotate the labels

plt.show()

# CITATION: https://stackoverflow.com/questions/32891211/limit-the-number-of-groups-shown-in-seaborn-countplot

# %%
# a function that describes the total popularity for each artist, we have to do some feature engineering here to 
# get the data in the proper format. This function will loop through all songs, their artist, and keep track of a total
# popularity variable for each artist
def total_popularity():
    artists = dict() # store artist and their respective popularity in a dictionary
    for i in range(len(spotify)): # loop through all songs
        artist = spotify['Artist'][i]
        artist = re.sub('[^A-Za-z0-9]+', '', artist) # filter artist names
        song_popularity = spotify["Popularity"][i].rstrip() # get song popularity
        try:
            song_popularity = int(song_popularity)            # attempt to convert song popularity to int
            if artists.get(artist) == None:                   # if artist does not exist, create new key in dict
                artists[artist] = int(song_popularity)
            else:                                             # add current song popularity to artists current popularity
                artists[artist] = int(artists.get(artist)) + int(song_popularity)
        except ValueError:
            # Handle the exception
            continue
    
    artists_name = list() # list of artists name
    artists_total_pop = list() # total popularity corresponsd to artist name indices in prev list
    
    for key in artists: # loop through dictinoary
        artists_name.append(key) # add artist to list
        artists_total_pop.append(int(artists[key])) # add artists total pop to list
    
    # remake current dictionary to be able to convert into dataframe easier later on
    artists = {
        "Artist": artists_name,
        "Total Popularity": artists_total_pop
    }
    
    return artists

total_popularity()
# Out:
# {'Artist': ['Mneskin',
#   'TheKidLAROI',
#   'OliviaRodrigo',
#   'EdSheeran',
#   'LilNasX',
#   'DojaCat',
#   'RauwAlejandro',
#   'BadBunny',
#   'DuaLipa',
#   'JBalvinMariaBecerra',
#   'BTS',
#   'JustinBieber',
#   'TheWeeknd',
#   'NioGarciaJBalvinBadBunny',
#   'MoraBadBunnySech',
#   'GlassAnimals',
#   'Farruko',
#   'PostMalone',
#   'RitonNightcrawlers',
#   'MaskedWolf',
#   'BrunoMarsAndersonPaakSilkSonic',
#   'CamilaCabello',
#   'SebastianYatraMykeTowers',
#   'HarryStyles',
#   'PoloG',
#   'DojaCatTheWeeknd',
#   'SechJhayCortez',
#   'BadBunnyJhayCortez',
#   'TINIMariaBecerra',
#   'JBalvinKAROLGNickyJamCrissinTotoyElFrioNatanShander',
#   'Tisto',
#   'Galantis',
#   '24kGoldn',
#   'TiagoPZKLITkillah',
#   'WisinJhayCortezAnuelAALosLegendariosMykeTowers',
#   'BellaPoarch',
#   'BizarrapNickyJam',
#   'MarcSeguRauwAlejandroPolGranch',
#   'BillieEilish',
#   'MajesticBoneyM',
#   'Marshmello',
#   'SurfCurse',
#   'JooGomes',
#   'RauwAlejandroMrNaisgai',
#   'Maroon5',
#   'OneRepublic',
#   'MeganTheeStallion',
#   'ATBTopicA7S',
#   'Giveon',
#   'TrinidadCardona',
#   'TheNeighbourhood',
#   'Maluma',
#   'LewisCapaldi',
#   'Smiley',
#   'SleepyHallow',
#   'KAROLGMariahAngeliq',
#   'JustinQuilesChimbalaZionLennox',
#   'Shouse',
#   'KaliUchis',
#   'GeraMXChristianNodal',
#   'LosLegendariosWisinJhayCortez',
#   'TonesAndI',
#   'Drake',
#   'BoBurnham',
#   'TravisScottHVME',
#   'JoelCorry',
#   'JoelCorryRAYEDavidGuetta',
#   'JustinWellingtonSmallJam',
#   'BellyTheWeekndYoungThug',
#   'DuncanLaurence',
#   'MoraJhayCortez',
#   'ArianaGrande',
#   'RAFCamoraBonezMC',
#   'NattiNatashaBeckyG',
#   'JBalvinSkrillex',
#   'WILLOW',
#   'Dave',
#   'MadisonBeer',
#   'BANDIDO',
#   'ImagineDragons',
#   'InternetMoney',
#   'BrunoMars',
#   'SAINtJHN',
#   'Sech',
#   'BeckyGElAlfa',
#   'Ingratax',
#   'PostMaloneSwaeLee',
#   'dhruv',
#   'CalvinHarris',
#   'LuanSantana',
#   'ShawnMendesCamilaCabello',
#   'MYATINIDuki',
#   'BadBunnyROSALA',
#   'DaBaby',
#   'ConanGray',
#   'TateMcRae',
#   'Avicii',
#   'VanceJoy',
#   'Nirvana',
#   'TrippieRedd',
#   'TomOdell',
#   'JamieMiller',
#   'Hozier',
#   'TomGrennan',
#   'GusttavoLima',
#   'CardiB',
#   'Khalid',
#   'Queen',
#   'MykeTowersJuhn',
#   'MEDUZA',
#   'TravisScott',
#   'Ofenbach',
#   'CamiloShawnMendes',
#   'LadyGagaBradleyCooper',
#   'CochiseNOT',
#   'MariFernandez',
#   'Coldplay',
#   'EmiliaDuki',
#   'JooGomesVitorFernandes',
#   'MatheusFernandesDilsinho',
#   'Vegedream',
#   'PopSmoke',
#   'AURORA',
#   'JuiceWRLD',
#   'LilTjay6LACK',
#   'PnkWillowSageHart',
#   'TheKillers',
#   'ThePolice',
#   'FleetwoodMac',
#   'JamesArthur',
#   'Normani',
#   'Powfubeabadoobee',
#   'AnneMarieNiallHoran',
#   'DrakeWizKidKyla',
#   'SarahCothran',
#   'WalkerHayes',
#   'JohnLegend',
#   'Saweetie',
#   'SZA',
#   'AnneMarieLittleMix',
#   'BlxstTyga',
#   'MCZaquinMCRick',
#   'TopicA7S',
#   'LusaSonza',
#   'RoddyRicch',
#   'Eminem',
#   'TrippieReddLilUziVert',
#   'KSI',
#   'TylerTheCreator',
#   'Pashanim',
#   'TionWayneRussMillions',
#   'NioGarciaFlowLaMovie',
#   'BLANCOSferaEbbasta',
#   'Regard',
#   'JohnMayer',
#   'McDaviMcPedrinhoMcDonJuan',
#   'SelenaGomez',
#   'Bas',
#   'IsraelRodolffoWesleySafado',
#   'TWICE',
#   'BIA',
#   'KaneBrownblackbear',
#   'AlexRoseRauwAlejandro',
#   'DjGuugaDJIvis',
#   'MalumaBeleRauwAlejandroMamboKingzDJLuianDarell',
#   'TheChainsmokersHalsey',
#   'Oasis',
#   'BrentFaiyaz',
#   'BigRedMachine',
#   'DJKhaled',
#   'StarBoi3',
#   'Lorde',
#   'ShirinDavid',
#   'CJ',
#   'IsraelRodolffo',
#   'MileyCyrus',
#   'GymClassHeroes',
#   'RauwAlejandroAnuelAA',
#   'sangiovanni',
#   'BizarrapEladioCarrion',
#   'ArcticMonkeys',
#   'Migos',
#   'FedezAchilleLauro',
#   'JBalvinDuaLipaBadBunny',
#   'Jawsh685JasonDerulo',
#   'CrissinTotoyElFrioNatanShander',
#   'Boza',
#   'TateMcRaeKhalid',
#   'SosoManess',
#   'JCole',
#   'XXXTENTACION',
#   'NathanEvans',
#   'MacklemoreRyanLewis',
#   'MachineGunKelly',
#   'MartinGarrix',
#   'RochyRDMykeTowersNickiNicole',
#   'LinkinPark',
#   'TheChainsmokersColdplay',
#   'RegardTroyeSivanTateMcRae',
#   'AvaMax',
#   'BlackEyedPeasShakira',
#   'MCKevinoChris',
#   'LadyGaga',
#   'LilBabyLilDurk',
#   'TOMORROWXTOGETHERSeori',
#   'LilTecca',
#   'YoungStonerLifeYoungThugGunna',
#   'ManuelTurizoRauwAlejandroMykeTowers',
#   'KAROLG',
#   'Ashnikko',
#   'AlokMcDonJuanDjGBR',
#   'MaluDJLucasBeat',
#   'LilMosey',
#   'GotyeKimbra',
#   'McPozedoRodoNeoBeatsMainstreet',
#   'BarbaraPravi',
#   'TwentyOnePilots',
#   'NickiMinaj',
#   'BlindChannel',
#   'GoA',
#   'ITZY',
#   'JoynerLucasLilBaby',
#   'BeachBunny',
#   'GjonsTears',
#   'LilTjay',
#   'Dream',
#   'DaiFreyr',
#   'BizarrapSnowThaProduct',
#   'NioGarciaCasperMagicoOzunaWisinYandelMykeTowersFlowLaMovie',
#   'MARINA',
#   'MykeTowers',
#   'MillyFarrukoNioGarciaJayWheelerAmenazzy',
#   'DaddyYankee',
#   'JPSaxe',
#   'RussMillionsTionWayne',
#   'DonToliver',
#   'BizarrapLGante',
#   'PinkSweat',
#   'Future',
#   '187StrassenbandeBonezMCFrauenarzt',
#   'NickyJamRomeoSantos',
#   'RaSaiaRodada',
#   'CamiloEvalunaMontaner',
#   'JorgeMateus',
#   'ElyOtto',
#   'BabyKeem',
#   'Anitta',
#   'ROS',
#   'TaylorSwift',
#   'JBalvinKhalid',
#   'DemiLovato',
#   'PoohShiesty',
#   'WisinMykeTowersLosLegendarios',
#   'HER',
#   'HVME',
#   'RittMomney',
#   'DiegoVictorHugoBrunoMarrone',
#   'ShawnMendes',
#   'MimiWebb',
#   'blackbear',
#   'KAROLGAnuelAAJBalvin',
#   'WesleySafadoOsBaresDaPisadinha',
#   'OsBaresDaPisadinha',
#   'JBalvinBadBunny',
#   'DMX',
#   'SebastianYatraGuaynaa',
#   'SechDaddyYankeeJBalvinROSALAFarruko',
#   'KHEADuki',
#   'SamFischerDemiLovato',
#   'KevinRoldanBryantMyersLyanno',
#   'JasonDerulo',
#   'MotherMother',
#   'DJIvis',
#   'RusherkingKHEADukiMariaBecerraLITkillahTiagoPZK',
#   'Maroon5WizKhalifa',
#   'JackHarlow',
#   'aha',
#   'CamiloElAlfa',
#   'JBalvin',
#   'KAROLGNickiMinaj',
#   'OzunaJBalvinChenchoCorleone',
#   'ZoeWees',
#   'DJIvisTarcsiodoAcordeon',
#   'JasonDeruloNuka',
#   'TheWeekndDaftPunk',
#   'HugoGuilherme',
#   'LanaDelRey',
#   'NickyJamMykeTowers',
#   'MalumaLennyTavrez',
#   'Camilo',
#   'HippieSabotage',
#   'JustinQuiles',
#   'DJSnake',
#   'Sia',
#   'JayWheelerDJNelsonMykeTowers',
#   'RobinSchulz',
#   'TameImpala',
#   'BANNERS',
#   'Pamungkas',
#   'BLACKPINK',
#   'NFHopsin',
#   'Madame',
#   'FrancescaMichielinFedez',
#   'AnuelAAOzuna',
#   'BoobaJSX',
#   'LilBaby',
#   'LelePons',
#   'OfenbachQuarterhead',
#   'LilPeep',
#   'BRNS',
#   'CTanganaNiodeElcheLaHngara',
#   'ArizonaZervas',
#   'CTanganaEdMaverick',
#   'Halsey',
#   'Clairo',
#   'BausaApache207',
#   'NF',
#   'SabrinaCarpenter',
#   'SaraKays',
#   'JasonDeruloMaroon5',
#   'OzunaCamilo',
#   'BizarrapNathyPeluso',
#   'MalumaTheWeeknd',
#   'TarcsiodoAcordeon',
#   'SurfMesa',
#   'SiaDavidGuetta',
#   'bennyblanco',
#   'BringMeTheHorizon',
#   'KaweMcLeleJP',
#   'DeanLewis',
#   'JerryDi',
#   'KASIMIR1441badmmzjayWILDBWOYS',
#   'BrentFaiyazDJDahi',
#   'ZAYN',
#   'MorganWallen',
#   'NioGarciaAnuelAAMykeTowersBrrayJuanka',
#   'MigrantesAlico',
#   'SamSmith',
#   '347aidan',
#   'RauwAlejandroJBalvin',
#   'ChrisBrownYoungThug',
#   'JuiceWRLDTheKidLAROI',
#   'AnneMarieKSIDigitalFarmAnimals',
#   'LusaSonzaPablloVittarAnitta',
#   'EricaBanks',
#   'Ozuna',
#   'Foushe',
#   'SechJBalvin',
#   'DuaLipaAngle',
#   'Apache207',
#   'Surfaces',
#   'PetterFerrazMenorNico',
#   'MarshmelloBastille',
#   'OsBaresDaPisadinhaXandAvio',
#   'KidCudi',
#   'MEDUZABeckyHillGoodboys',
#   'CORPSESavageGap',
#   'MariahCarey',
#   'Wham',
#   'BrendaLee',
#   'BobbyHelms',
#   'MichaelBubl',
#   'AndyWilliams',
#   'KellyClarkson',
#   'JosFeliciano',
#   'DeanMartin',
#   'FrankSinatra',
#   'TheRonettes',
#   'BandAid',
#   'PaulMcCartney',
#   'JohnLennonYokoOno',
#   'NatKingCole',
#   'BingCrosbyKenDarbySingersJohnScottTrotterHisOrchestra',
#   'PlayboiCarti',
#   'BurlIves',
#   'ThePogues',
#   'ShakinStevens',
#   'ElvisPresley',
#   'ChuckBerry',
#   'TheJackson5',
#   'KylieMinogue',
#   'PerryComoTheFontaneSisters',
#   'DarleneLove',
#   'EltonJohn',
#   'JonasEsticado',
#   'DarylHallJohnOates',
#   'BritneySpears',
#   'BrettEldredge',
#   'JonasBrothers',
#   'GwenStefani',
#   'IdinaMenzel',
#   'EarthaKittHenriReneHisOrchestra',
#   'MykolaDmytrovychLeontovychJohnWilliams',
#   'StevieWonder',
#   'BruceSpringsteen',
#   'LeonaLewis',
#   'TheBeachBoys',
#   'LiamPayne',
#   'MeghanTrainor',
#   'BingCrosby',
#   'Pentatonix',
#   'DonnyHathaway',
#   'TonyBennett',
#   'KatyPerry',
#   'NSYNC',
#   'Eagles',
#   'ToryLanezJackHarlow',
#   'salemilese',
#   'BadBunnyJowellRandyengoFlow',
#   'StudioKillers',
#   'BadBunnyABRA',
#   'TrioVegabajeo',
#   'JhayCortezBadBunny',
#   'SferaEbbasta',
#   'CleanBanditMabel',
#   'ChristianNodalngelaAguilar',
#   'MasterKG',
#   'AyaNakamura',
#   'JustinTimberlake',
#   '21SavageMetroBoomin',
#   'Wallows',
#   'DanShay',
#   'Vedo',
#   'ManuelTurizo',
#   'StaySolidRocky',
#   'FutureLilUziVert',
#   'KaneBrown',
#   'KDAMadisonBeerGIDLELexieLiuJairaBurnsSeraphineLeagueofLegends',
#   'OctavianSkepta',
#   'TyDollaign',
#   'LittleMix',
#   'MAX',
#   'NellyFurtadoTimbaland',
#   'Labrinth',
#   'AnuelAABadBunny',
#   'Kina',
#   'DDG',
#   'LukeCombs',
#   'Joji',
#   'DaddyYankeeAnuelAAKendoKaponi',
#   'CaliYElDandeeDannaPaola',
#   'KHEA',
#   'OzunaKAROLGMykeTowers',
#   'MichaelJackson',
#   'BonezMC',
#   'ACDC',
#   'MoneyMan',
#   'BigSean',
#   'BlackEyedPeasOzunaJReySoul',
#   'LauvConanGray',
#   'MarshmelloDemiLovato',
#   'THESCOTTSTravisScottKidCudi',
#   'TruenoBizarrapTaiuTATOOL',
#   'Passenger',
#   'MelanieMartinez',
#   'KygoOneRepublic',
#   'Adele',
#   'AliGatie',
#   'CurtisWaters',
#   'GEazy',
#   '13OrganisSCHKofsJulNapsSosoManessElamsSoldaHouari',
#   'BebeRexha',
#   'ROSALA',
#   'Gunna',
#   'RauwAlejandroDalexLennyTavrez',
#   'NoahCyrus',
#   'BENEEGusDapperton',
#   'Niack',
#   'FeidJBalvinJustinQuiles',
#   'ChrisBrown',
#   'BrysonTiller',
#   'WhoHeem',
#   'JojiDiplo',
#   'BeaMiller',
#   'JojiBENEE',
#   'JuiceWRLDPoloG',
#   'HarryNach',
#   'KendrickLamarJayRock',
#   'InternetMoneyDiplo',
#   'EarthWindFire',
#   'RegardRAYE',
#   'DamsoHamza',
#   'Damso',
#   '6ix9ine',
#   'KygoDonnaSummer',
#   'OzunaDojaCatSia',
#   'SZATheNeptunesPharrellWilliamsTyDollaign',
#   'Matu',
#   'AlexRoseRafaPabn',
#   'BonezMCMaxwell',
#   'HeadieOne',
#   'Nea',
#   'BeyoncMeganTheeStallion',
#   'RobinSchulzWes',
#   'KDAGIDLEWolftylaBeaMillerLeagueofLegends',
#   'McZaacAnittaTyga',
#   'PeachTreeRascals',
#   'BlackEyedPeasJBalvin',
#   'KitschKriegJamuleSFR',
#   'KygoTinaTurner',
#   'Conkarah',
#   'Cordae',
#   'JACKBOYSTravisScott',
#   'JowellRandyJBalvin',
#   'AnuelAA',
#   'RodWave',
#   'JustinQuilesDaddyYankeeElAlfa',
#   'InternetMoneyGunnaDonToliverNAV',
#   'CapitalBraCro',
#   'FeidJustinQuiles',
#   'BausaJuju',
#   'Mustard',
#   'JasonMraz',
#   '5SecondsofSummer',
#   'S1mba',
#   'HeadieOneDrake',
#   'RauwAlejandroChenchoCorleone',
#   'JasonDeruloPuriJhorrmountain',
#   'twocolors',
#   'KygoWhitneyHouston',
#   'Juanfran',
#   'NLEChoppa',
#   'VIZETomGregory',
#   'AAPFerg',
#   'ElAlfaChaelProduciendo',
#   'CapitalBraCluesoKCRebell',
#   'OneDirection',
#   'Ufo361Sonus030',
#   'DripReport',
#   'Logic',
#   'StaySolidRockyLilUziVert',
#   'TrevorDaniel',
#   'Luciano',
#   'LilNasXBillyRayCyrus',
#   'AnuelAADaddyYankeeKAROLGOzunaJBalvin',
#   'DalexLennyTavrezChenchoCorleoneJuhnDmeloFlow',
#   'BadBunnySech',
#   'DmeloFlowArcangelSech',
#   'KontraK',
#   'KanyeWestTravisScott',
#   'RedVelvetIRENESEULGI',
#   'SamFischer',
#   'Y2Kbbno',
#   'SleepyHallowFoushe',
#   'TylaYaweh',
#   'ianndior',
#   'JhayCortezJBalvinBadBunny',
#   'RauwAlejandroChenchoCorleoneKEVVOBryantMyersLyannoDalex',
#   'Journey',
#   'Beyonc',
#   'MiksuMacloudSummerCemLucianoJamule',
#   'LilUziVert',
#   'Lauv',
#   'PanicAtTheDisco',
#   'BoomdabashAlessandraAmoroso',
#   'KhalidDisclosure',
#   'BadBunnyDonOmar',
#   'Tyga',
#   'CapitalBraBozza',
#   'ABoogieWitdaHoodie',
#   'Bosh',
#   'AlidaRobinSchulz',
#   'Alexander23',
#   'MEDUZAGoodboys',
#   'BadBunnyDaddyYankee',
#   'PUBLIC',
#   'PopSmokeRowdyRebel',
#   'Shablo',
#   'Ufo361CLINE',
#   'NatalieTaylor',
#   'NAV',
#   'KygoZaraLarssonTyga',
#   'AlecBenjamin',
#   'PARTYNEXTDOORRihanna',
#   'KCRebellSummerCem',
#   'ChildishGambino',
#   'RauwAlejandroFarruko',
#   'BadBunnyNickyJam',
#   'BadBunnyTainy',
#   'YNWMelly',
#   'KygoKimPetras',
#   'KALIMUfo361',
#   'LilYachty',
#   'KygoZakAbel',
#   'AgustD',
#   'CapitalBra',
#   'YandelBadBunny',
#   'BadBunnyZionLennox',
#   'IU',
#   'VicetoneTonyIgy',
#   'ArcangelSechRomeoSantos',
#   'jxdn',
#   'SechDaddyYankee',
#   'NickyJamDaddyYankee',
#   'PoloGStunna4VegasNLEChoppaMikeWiLLMadeIt',
#   'GHerboJuiceWRLDLilUziVertChancetheRapper',
#   'TrippieReddPARTYNEXTDOOR',
#   'KinaAdrianaProenza',
#   'BadBunnyGabriela',
#   'BandaMSdeSergioLizrragaSnoopDogg',
#   'CapitalBraLoredana',
#   'Ashe',
#   'Kehlani',
#   'FutureDrakeYoungThug',
#   'NAVGunna',
#   'Ufo361',
#   'ToryLanez',
#   'RauwAlejandroAnuelAANattiNatashaFarrukoLunay',
#   'BROCKHAMPTON',
#   'ShakiraAnuelAA',
#   'The1975',
#   'AlanWalkerAvaMax',
#   'CamiloPedroCap',
#   'EllieGoulding',
#   'RvssianAnuelAAJuiceWRLD',
#   'KygoSashaAlexSloan',
#   'KAROLGAnuelAA',
#   'DominicFike',
#   'Samra',
#   'TheChainsmokersILLENIUMLennonStella',
#   'LunayMykeTowersOzunaChenchoCorleoneRauwAlejandro',
#   'PoloGStunna4Vegas',
#   'SubUrban',
#   'Lizzo',
#   'Bazzi',
#   'ShivaEiffel65',
#   'ZunaLoredanaSRNO',
#   'BadBunnyYaviah',
#   'JhayCortezAnuelAAJBalvin',
#   'JBalvinSkyRompiendo',
#   'NiallHoran',
#   'JBalvinMrEazi',
#   'DardanMonet192',
#   'ChristianNodal',
#   'JhenAiko',
#   'BadBunnyAnuelAA',
#   'LilUziVert21Savage',
#   'BadBunnyDukiPabloChillE',
#   'Ninho',
#   'BadBunnyengoFlow',
#   'BadBunnyMora',
#   'SZAJustinTimberlake',
#   'NickyJamAnuelAA',
#   'Tainy',
#   'HenriqueJuliano',
#   'Residente',
#   'BadBunnyKendoKaponiArcangel',
#   'LauvTroyeSivan',
#   'BadBunnyMykeTowers',
#   'DaddyYankeeSech',
#   'LunayOzunaAnuelAA',
#   'LauvLANY',
#   'DalexLennyTavrezAnittaNattiNatashaFarrukoJustinQuiles',
#   'ArcangelBadBunny',
#   'TOKYOSREVENGE',
#   'Stormzy',
#   'CapitalBraSamra',
#   'RichMusicLTDSechDalexJustinQuilesLennyTavrezFeidWisinZion',
#   'LunayDaddyYankeeBadBunny',
#   'SHAED',
#   'ThiaguinhoMTMilaJSoModeOuro',
#   'RichMusicLTDSechDalexJustinQuilesLennyTavrezFeid',
#   'PEDROSAMPAIOFelipeOriginalJSoModeOuro',
#   'KCAMP',
#   'SechOzuna',
#   'MajorLazerDiplo',
#   'ReikJBalvinLaloEbratt',
#   'DalexSech',
#   'MigosTravisScottYoungThug',
#   'KygoSandroCavazza',
#   'JokerBraVIZE',
#   'MacMiller',
#   'JustinBieberQuavo',
#   'AntSaunders',
#   'AnneMarie',
#   'LilWayne',
#   'JustinBieberKehlani',
#   'ROSALAOzuna',
#   'JustinQuilesNattiNatashaFarruko',
#   'Piso21ChristianNodal',
#   'DJSnakeJBalvin',
#   'RedVelvet',
#   'ROSALAJBalvinElGuincho',
#   'TravisScottYoungThug',
#   'DaddyYankeeSnow',
#   'SechOzunaAnuelAADarellNickyJam',
#   'MatthewWilder',
#   'JujuLoredanaMiksuMacloud',
#   'RitonOliverHeldens',
#   'Shakira',
#   'MeekMill',
#   'JColeYoungThug',
#   'Gzuz',
#   'SamraELIF',
#   'MurdaEzhel',
#   'SamFeldt',
#   'Ufo361Future',
#   'Gambi',
#   'MaesBooba',
#   'IdinaMenzelAURORA',
#   'Mabel',
#   'TrippieReddDaBaby',
#   'PedroCapFarruko',
#   'TheChainsmokersKygo',
#   'JACKBOYSSheckWes',
#   'FrenchMontana',
#   'SHAEDZAYN',
#   'JACKBOYSPopSmokeTravisScott',
#   'JACKBOYS',
#   'AnittaLexaLusaSonza',
#   'GradurHeussLenfoir',
#   'DadBoladoTatiZaquiOIK'],
#  'Total Popularity': [362,
#   642,
#   1071,
#   670,
#   511,
#   1283,
#   488,
#   2062,
#   955,
#   95,
#   2181,
#   2005,
#   1549,
#   93,
#   91,
#   85,
#   170,
#   804,
#   92,
#   89,
#   92,
#   316,
#   91,
#   415,
#   849,
#   89,
#   89,
#   86,
#   90,
#   89,
#   90,
#   89,
#   316,
#   89,
#   89,
#   89,
#   88,
#   88,
#   707,
#   49,
#   169,
#   89,
#   167,
#   87,
#   391,
#   162,
#   428,
#   88,
#   87,
#   87,
#   172,
#   460,
#   249,
#   83,
#   85,
#   87,
#   87,
#   87,
#   88,
#   87,
#   88,
#   162,
#   1337,
#   165,
#   87,
#   87,
#   87,
#   87,
#   80,
#   84,
#   87,
#   1284,
#   78,
#   86,
#   2,
#   85,
#   156,
#   156,
#   85,
#   336,
#   235,
#   245,
#   72,
#   255,
#   86,
#   86,
#   82,
#   86,
#   238,
#   85,
#   82,
#   85,
#   86,
#   995,
#   168,
#   86,
#   169,
#   78,
#   77,
#   85,
#   67,
#   85,
#   74,
#   80,
#   151,
#   167,
#   289,
#   222,
#   85,
#   85,
#   694,
#   85,
#   83,
#   83,
#   85,
#   84,
#   138,
#   83,
#   81,
#   83,
#   0,
#   1970,
#   77,
#   2210,
#   85,
#   83,
#   75,
#   83,
#   84,
#   166,
#   75,
#   85,
#   83,
#   84,
#   71,
#   83,
#   84,
#   220,
#   84,
#   78,
#   84,
#   84,
#   84,
#   80,
#   376,
#   1448,
#   79,
#   266,
#   1073,
#   155,
#   84,
#   85,
#   83,
#   84,
#   151,
#   84,
#   970,
#   76,
#   82,
#   228,
#   80,
#   80,
#   83,
#   79,
#   84,
#   84,
#   156,
#   78,
#   77,
#   391,
#   83,
#   81,
#   141,
#   81,
#   83,
#   440,
#   163,
#   79,
#   82,
#   81,
#   166,
#   438,
#   82,
#   83,
#   158,
#   89,
#   83,
#   80,
#   79,
#   1196,
#   569,
#   83,
#   83,
#   460,
#   232,
#   82,
#   83,
#   82,
#   83,
#   365,
#   82,
#   81,
#   809,
#   162,
#   81,
#   225,
#   229,
#   79,
#   0,
#   158,
#   80,
#   80,
#   152,
#   76,
#   82,
#   72,
#   379,
#   147,
#   72,
#   75,
#   227,
#   81,
#   81,
#   69,
#   232,
#   76,
#   70,
#   78,
#   81,
#   73,
#   227,
#   79,
#   72,
#   82,
#   84,
#   372,
#   80,
#   79,
#   330,
#   67,
#   79,
#   80,
#   146,
#   210,
#   80,
#   75,
#   141,
#   145,
#   3558,
#   80,
#   205,
#   75,
#   79,
#   74,
#   87,
#   81,
#   79,
#   265,
#   81,
#   218,
#   0,
#   73,
#   149,
#   160,
#   145,
#   0,
#   80,
#   75,
#   77,
#   77,
#   82,
#   81,
#   73,
#   78,
#   74,
#   301,
#   84,
#   78,
#   559,
#   80,
#   81,
#   78,
#   73,
#   79,
#   163,
#   77,
#   205,
#   76,
#   78,
#   300,
#   80,
#   151,
#   145,
#   197,
#   82,
#   74,
#   352,
#   79,
#   81,
#   634,
#   66,
#   0,
#   67,
#   146,
#   72,
#   691,
#   77,
#   79,
#   82,
#   83,
#   75,
#   156,
#   70,
#   285,
#   81,
#   68,
#   69,
#   76,
#   78,
#   78,
#   75,
#   77,
#   77,
#   67,
#   81,
#   78,
#   150,
#   144,
#   72,
#   80,
#   76,
#   70,
#   76,
#   137,
#   507,
#   75,
#   74,
#   618,
#   79,
#   73,
#   80,
#   75,
#   73,
#   1,
#   72,
#   133,
#   72,
#   70,
#   73,
#   427,
#   80,
#   66,
#   82,
#   68,
#   758,
#   82,
#   77,
#   112,
#   63,
#   58,
#   56,
#   147,
#   55,
#   49,
#   49,
#   139,
#   127,
#   50,
#   51,
#   102,
#   53,
#   53,
#   51,
#   64,
#   49,
#   55,
#   47,
#   49,
#   0,
#   44,
#   42,
#   49,
#   45,
#   43,
#   72,
#   43,
#   43,
#   44,
#   349,
#   44,
#   47,
#   41,
#   51,
#   0,
#   44,
#   42,
#   0,
#   51,
#   86,
#   44,
#   60,
#   42,
#   29,
#   250,
#   41,
#   44,
#   80,
#   76,
#   79,
#   72,
#   70,
#   56,
#   81,
#   246,
#   78,
#   75,
#   78,
#   141,
#   78,
#   784,
#   81,
#   83,
#   79,
#   74,
#   77,
#   257,
#   79,
#   73,
#   73,
#   151,
#   138,
#   72,
#   82,
#   80,
#   76,
#   82,
#   74,
#   80,
#   552,
#   69,
#   76,
#   71,
#   72,
#   68,
#   367,
#   83,
#   74,
#   141,
#   74,
#   73,
#   0,
#   79,
#   75,
#   75,
#   80,
#   75,
#   77,
#   150,
#   68,
#   144,
#   72,
#   69,
#   75,
#   325,
#   75,
#   81,
#   77,
#   127,
#   70,
#   80,
#   68,
#   61,
#   72,
#   75,
#   67,
#   78,
#   71,
#   75,
#   70,
#   80,
#   78,
#   62,
#   62,
#   253,
#   71,
#   79,
#   74,
#   70,
#   74,
#   59,
#   69,
#   77,
#   73,
#   67,
#   70,
#   68,
#   76,
#   78,
#   68,
#   74,
#   70,
#   65,
#   152,
#   66,
#   338,
#   185,
#   73,
#   82,
#   56,
#   0,
#   62,
#   80,
#   80,
#   352,
#   73,
#   68,
#   76,
#   69,
#   79,
#   79,
#   67,
#   200,
#   61,
#   61,
#   69,
#   60,
#   163,
#   52,
#   73,
#   60,
#   62,
#   47,
#   117,
#   81,
#   77,
#   77,
#   74,
#   75,
#   62,
#   64,
#   70,
#   80,
#   77,
#   72,
#   73,
#   68,
#   77,
#   73,
#   81,
#   61,
#   64,
#   2001,
#   298,
#   81,
#   0,
#   76,
#   72,
#   125,
#   57,
#   186,
#   64,
#   71,
#   79,
#   79,
#   79,
#   77,
#   64,
#   66,
#   65,
#   76,
#   67,
#   68,
#   82,
#   74,
#   114,
#   71,
#   75,
#   71,
#   81,
#   220,
#   66,
#   60,
#   204,
#   72,
#   77,
#   53,
#   76,
#   67,
#   75,
#   71,
#   69,
#   72,
#   62,
#   72,
#   74,
#   76,
#   69,
#   78,
#   62,
#   69,
#   58,
#   75,
#   68,
#   63,
#   70,
#   222,
#   214,
#   70,
#   75,
#   72,
#   59,
#   77,
#   74,
#   76,
#   64,
#   70,
#   63,
#   77,
#   166,
#   77,
#   69,
#   41,
#   73,
#   219,
#   147,
#   56,
#   54,
#   75,
#   70,
#   63,
#   208,
#   62,
#   34,
#   71,
#   72,
#   69,
#   70,
#   69,
#   54,
#   69,
#   77,
#   68,
#   70,
#   75,
#   124,
#   65,
#   66,
#   77,
#   64,
#   66,
#   68,
#   72,
#   67,
#   72,
#   74,
#   72,
#   52,
#   73,
#   75,
#   73,
#   57,
#   66,
#   64,
#   61,
#   67,
#   29,
#   0,
#   63,
#   59,
#   15,
#   63,
#   708,
#   77,
#   70,
#   146,
#   60,
#   61,
#   74,
#   72,
#   74,
#   77,
#   76,
#   75,
#   68,
#   3,
#   74,
#   73,
#   62,
#   76,
#   83,
#   79,
#   72,
#   62,
#   57,
#   57,
#   73,
#   48,
#   59,
#   65,
#   74,
#   79,
#   65,
#   76,
#   67,
#   69,
#   59,
#   73,
#   77,
#   56,
#   64,
#   62,
#   60]}

# %%
# Create a visualization for the total popularity for each artist
sns.set_theme(style="whitegrid")
sns.set(rc={'figure.figsize':(9,6)})
dictionary = total_popularity()
spotify_pop = pd.DataFrame(dictionary)
spotify_pop.sort_values(by=['Total Popularity'], ascending=False, inplace=True)
print(spotify_pop)

sns.barplot(x="Artist", y="Total Popularity", data=spotify_pop[:10], palette="rocket")

plt.xticks(rotation = 70) # rotate the labels

plt.show()

### CITATION: https://seaborn.pydata.org/generated/seaborn.countplot.html
# Out:
#                           Artist  Total Popularity
# 248                  TaylorSwift              3558
# 123                    JuiceWRLD              2210
# 10                           BTS              2181
# 7                       BadBunny              2062
# 11                  JustinBieber              2005
# ..                           ...               ...
# 554  BoomdabashAlessandraAmoroso                 0
# 265        SebastianYatraGuaynaa                 0
# 260         KAROLGAnuelAAJBalvin                 0
# 208                       KAROLG                 0
# 393                 StevieWonder                 0
#
# [712 rows x 2 columns]

# %%
# a function that describes the total stream count for each artist, we have to do some feature engineering here to 
# get the data in the proper format. This function will loop through all songs, their artist, and keep track of a total
# stream count variable for each artist
def total_streams():
    artists = dict() # store artist and their respective total streams in a dictionary
    for i in range(len(spotify)): # loop through all songs
        artist = spotify['Artist'][i]
        artist = re.sub('[^A-Za-z0-9]+', '', artist) # filter artist names
        song_streams = spotify['Streams'][i].rstrip().replace(",", "") # get song stream count
        try:
            song_streams = int(song_streams)            # attempt to convert song stream count to int
            if artists.get(artist) == None:                   # if artist does not exist, create new key in dict
                artists[artist] = int(song_streams)
            else:                                             # add current song stream count to artists current stream count
                artists[artist] = int(artists.get(artist)) + int(song_streams)
        except ValueError:
            # Handle the exception
            continue
    
    artists_name = list() # list of artists name
    artists_total_streams = list() # total stream count corresponsd to artist name indices in prev list
    
    for key in artists: # loop through dictinoary
        artists_name.append(key) # add artist to list
        artists_total_streams.append(int(artists[key])) # add artists total stream count to list

    # remake current dictionary to be able to convert into dataframe easier later on
    artists = {
        "Artist": artists_name,
        "Total Streams": artists_total_streams
    }
    
    return artists

total_streams()
# Out:
# {'Artist': ['Mneskin',
#   'TheKidLAROI',
#   'OliviaRodrigo',
#   'EdSheeran',
#   'LilNasX',
#   'DojaCat',
#   'RauwAlejandro',
#   'BadBunny',
#   'DuaLipa',
#   'JBalvinMariaBecerra',
#   'BTS',
#   'JustinBieber',
#   'TheWeeknd',
#   'NioGarciaJBalvinBadBunny',
#   'MoraBadBunnySech',
#   'GlassAnimals',
#   'Farruko',
#   'PostMalone',
#   'RitonNightcrawlers',
#   'MaskedWolf',
#   'BrunoMarsAndersonPaakSilkSonic',
#   'CamilaCabello',
#   'SebastianYatraMykeTowers',
#   'HarryStyles',
#   'PoloG',
#   'DojaCatTheWeeknd',
#   'SechJhayCortez',
#   'BadBunnyJhayCortez',
#   'TINIMariaBecerra',
#   'JBalvinKAROLGNickyJamCrissinTotoyElFrioNatanShander',
#   'Tisto',
#   'Galantis',
#   '24kGoldn',
#   'TiagoPZKLITkillah',
#   'WisinJhayCortezAnuelAALosLegendariosMykeTowers',
#   'BellaPoarch',
#   'BizarrapNickyJam',
#   'MarcSeguRauwAlejandroPolGranch',
#   'BillieEilish',
#   'MajesticBoneyM',
#   'Marshmello',
#   'SurfCurse',
#   'JooGomes',
#   'RauwAlejandroMrNaisgai',
#   'Maroon5',
#   'OneRepublic',
#   'MeganTheeStallion',
#   'ATBTopicA7S',
#   'Giveon',
#   'TrinidadCardona',
#   'TheNeighbourhood',
#   'Maluma',
#   'LewisCapaldi',
#   'Smiley',
#   'SleepyHallow',
#   'KAROLGMariahAngeliq',
#   'JustinQuilesChimbalaZionLennox',
#   'Shouse',
#   'KaliUchis',
#   'GeraMXChristianNodal',
#   'LosLegendariosWisinJhayCortez',
#   'TonesAndI',
#   'Drake',
#   'BoBurnham',
#   'TravisScottHVME',
#   'JoelCorry',
#   'JoelCorryRAYEDavidGuetta',
#   'JustinWellingtonSmallJam',
#   'BellyTheWeekndYoungThug',
#   'DuncanLaurence',
#   'MoraJhayCortez',
#   'ArianaGrande',
#   'RAFCamoraBonezMC',
#   'NattiNatashaBeckyG',
#   'JBalvinSkrillex',
#   'WILLOW',
#   'Dave',
#   'MadisonBeer',
#   'BANDIDO',
#   'ImagineDragons',
#   'InternetMoney',
#   'BrunoMars',
#   'SAINtJHN',
#   'Sech',
#   'BeckyGElAlfa',
#   'Ingratax',
#   'PostMaloneSwaeLee',
#   'dhruv',
#   'CalvinHarris',
#   'LuanSantana',
#   'ShawnMendesCamilaCabello',
#   'MYATINIDuki',
#   'BadBunnyROSALA',
#   'DaBaby',
#   'ConanGray',
#   'TateMcRae',
#   'Avicii',
#   'VanceJoy',
#   'Nirvana',
#   'TrippieRedd',
#   'TomOdell',
#   'JamieMiller',
#   'Hozier',
#   'TomGrennan',
#   'GusttavoLima',
#   'CardiB',
#   'Khalid',
#   'Queen',
#   'MykeTowersJuhn',
#   'MEDUZA',
#   'TravisScott',
#   'Ofenbach',
#   'CamiloShawnMendes',
#   'LadyGagaBradleyCooper',
#   'CochiseNOT',
#   'MariFernandez',
#   'Coldplay',
#   'EmiliaDuki',
#   'JooGomesVitorFernandes',
#   'MatheusFernandesDilsinho',
#   'Vegedream',
#   'PopSmoke',
#   'AURORA',
#   'JuiceWRLD',
#   'LilTjay6LACK',
#   'PnkWillowSageHart',
#   'TheKillers',
#   'ThePolice',
#   'FleetwoodMac',
#   'JamesArthur',
#   'Normani',
#   'Powfubeabadoobee',
#   'AnneMarieNiallHoran',
#   'DrakeWizKidKyla',
#   'SarahCothran',
#   'WalkerHayes',
#   'JohnLegend',
#   'Saweetie',
#   'SZA',
#   'AnneMarieLittleMix',
#   'BlxstTyga',
#   'MCZaquinMCRick',
#   'TopicA7S',
#   'LusaSonza',
#   'RoddyRicch',
#   'Eminem',
#   'TrippieReddLilUziVert',
#   'KSI',
#   'TylerTheCreator',
#   'Pashanim',
#   'TionWayneRussMillions',
#   'NioGarciaFlowLaMovie',
#   'BLANCOSferaEbbasta',
#   'Regard',
#   'JohnMayer',
#   'McDaviMcPedrinhoMcDonJuan',
#   'SelenaGomez',
#   'Bas',
#   'IsraelRodolffoWesleySafado',
#   'TWICE',
#   'BIA',
#   'KaneBrownblackbear',
#   'AlexRoseRauwAlejandro',
#   'DjGuugaDJIvis',
#   'MalumaBeleRauwAlejandroMamboKingzDJLuianDarell',
#   'TheChainsmokersHalsey',
#   'Oasis',
#   'BrentFaiyaz',
#   'BigRedMachine',
#   'DJKhaled',
#   'StarBoi3',
#   'Lorde',
#   'ShirinDavid',
#   'CJ',
#   'IsraelRodolffo',
#   'MileyCyrus',
#   'GymClassHeroes',
#   'RauwAlejandroAnuelAA',
#   'sangiovanni',
#   'BizarrapEladioCarrion',
#   'ArcticMonkeys',
#   'Migos',
#   'FedezAchilleLauro',
#   'JBalvinDuaLipaBadBunny',
#   'Jawsh685JasonDerulo',
#   'CrissinTotoyElFrioNatanShander',
#   'Boza',
#   'TateMcRaeKhalid',
#   'SosoManess',
#   'JCole',
#   'XXXTENTACION',
#   'NathanEvans',
#   'MacklemoreRyanLewis',
#   'MachineGunKelly',
#   'MartinGarrix',
#   'RochyRDMykeTowersNickiNicole',
#   'LinkinPark',
#   'TheChainsmokersColdplay',
#   'RegardTroyeSivanTateMcRae',
#   'AvaMax',
#   'BlackEyedPeasShakira',
#   'MCKevinoChris',
#   'LadyGaga',
#   'LilBabyLilDurk',
#   'TOMORROWXTOGETHERSeori',
#   'LilTecca',
#   'YoungStonerLifeYoungThugGunna',
#   'ManuelTurizoRauwAlejandroMykeTowers',
#   'KAROLG',
#   'Ashnikko',
#   'AlokMcDonJuanDjGBR',
#   'MaluDJLucasBeat',
#   'LilMosey',
#   'GotyeKimbra',
#   'McPozedoRodoNeoBeatsMainstreet',
#   'BarbaraPravi',
#   'TwentyOnePilots',
#   'NickiMinaj',
#   'BlindChannel',
#   'GoA',
#   'ITZY',
#   'JoynerLucasLilBaby',
#   'BeachBunny',
#   'GjonsTears',
#   'LilTjay',
#   'Dream',
#   'DaiFreyr',
#   'BizarrapSnowThaProduct',
#   'NioGarciaCasperMagicoOzunaWisinYandelMykeTowersFlowLaMovie',
#   'MARINA',
#   'MykeTowers',
#   'MillyFarrukoNioGarciaJayWheelerAmenazzy',
#   'DaddyYankee',
#   'JPSaxe',
#   'RussMillionsTionWayne',
#   'DonToliver',
#   'BizarrapLGante',
#   'PinkSweat',
#   'Future',
#   '187StrassenbandeBonezMCFrauenarzt',
#   'NickyJamRomeoSantos',
#   'RaSaiaRodada',
#   'CamiloEvalunaMontaner',
#   'JorgeMateus',
#   'ElyOtto',
#   'BabyKeem',
#   'Anitta',
#   'ROS',
#   'TaylorSwift',
#   'JBalvinKhalid',
#   'DemiLovato',
#   'PoohShiesty',
#   'WisinMykeTowersLosLegendarios',
#   'HER',
#   'HVME',
#   'RittMomney',
#   'DiegoVictorHugoBrunoMarrone',
#   'ShawnMendes',
#   'MimiWebb',
#   'blackbear',
#   'KAROLGAnuelAAJBalvin',
#   'WesleySafadoOsBaresDaPisadinha',
#   'OsBaresDaPisadinha',
#   'JBalvinBadBunny',
#   'DMX',
#   'SebastianYatraGuaynaa',
#   'SechDaddyYankeeJBalvinROSALAFarruko',
#   'KHEADuki',
#   'SamFischerDemiLovato',
#   'KevinRoldanBryantMyersLyanno',
#   'JasonDerulo',
#   'MotherMother',
#   'DJIvis',
#   'RusherkingKHEADukiMariaBecerraLITkillahTiagoPZK',
#   'Maroon5WizKhalifa',
#   'JackHarlow',
#   'aha',
#   'CamiloElAlfa',
#   'RodWave',
#   'JBalvin',
#   'KAROLGNickiMinaj',
#   'OzunaJBalvinChenchoCorleone',
#   'ZoeWees',
#   'DJIvisTarcsiodoAcordeon',
#   'JasonDeruloNuka',
#   'TheWeekndDaftPunk',
#   'HugoGuilherme',
#   'LanaDelRey',
#   'NickyJamMykeTowers',
#   'MalumaLennyTavrez',
#   'Camilo',
#   'HippieSabotage',
#   'JustinQuiles',
#   'DJSnake',
#   'Sia',
#   'JayWheelerDJNelsonMykeTowers',
#   'RobinSchulz',
#   'TameImpala',
#   'BANNERS',
#   'Pamungkas',
#   'BLACKPINK',
#   'NFHopsin',
#   'Madame',
#   'FrancescaMichielinFedez',
#   'AnuelAAOzuna',
#   'BoobaJSX',
#   'LilBaby',
#   'LelePons',
#   'OfenbachQuarterhead',
#   'LilPeep',
#   'BRNS',
#   'CTanganaNiodeElcheLaHngara',
#   'ArizonaZervas',
#   'CTanganaEdMaverick',
#   'Halsey',
#   'Clairo',
#   'BausaApache207',
#   'NF',
#   'SabrinaCarpenter',
#   'SaraKays',
#   'JasonDeruloMaroon5',
#   'OzunaCamilo',
#   'BizarrapNathyPeluso',
#   'MalumaTheWeeknd',
#   'TarcsiodoAcordeon',
#   'SurfMesa',
#   'SiaDavidGuetta',
#   'bennyblanco',
#   'BringMeTheHorizon',
#   'KaweMcLeleJP',
#   'DeanLewis',
#   'JerryDi',
#   'KASIMIR1441badmmzjayWILDBWOYS',
#   'BrentFaiyazDJDahi',
#   'ZAYN',
#   'MorganWallen',
#   'NioGarciaAnuelAAMykeTowersBrrayJuanka',
#   'MigrantesAlico',
#   'SamSmith',
#   '347aidan',
#   'RauwAlejandroJBalvin',
#   'ChrisBrownYoungThug',
#   'JuiceWRLDTheKidLAROI',
#   'AnneMarieKSIDigitalFarmAnimals',
#   'LusaSonzaPablloVittarAnitta',
#   'EricaBanks',
#   'Ozuna',
#   'Foushe',
#   'SechJBalvin',
#   'DuaLipaAngle',
#   'Apache207',
#   'Surfaces',
#   'PetterFerrazMenorNico',
#   'MarshmelloBastille',
#   'OsBaresDaPisadinhaXandAvio',
#   'KidCudi',
#   'MEDUZABeckyHillGoodboys',
#   'CORPSESavageGap',
#   'MariahCarey',
#   'Wham',
#   'BrendaLee',
#   'BobbyHelms',
#   'MichaelBubl',
#   'AndyWilliams',
#   'KellyClarkson',
#   'JosFeliciano',
#   'DeanMartin',
#   'FrankSinatra',
#   'TheRonettes',
#   'BandAid',
#   'PaulMcCartney',
#   'JohnLennonYokoOno',
#   'ChrisRea',
#   'NatKingCole',
#   'BingCrosbyKenDarbySingersJohnScottTrotterHisOrchestra',
#   'PlayboiCarti',
#   'BurlIves',
#   'ThePogues',
#   'ShakinStevens',
#   'ElvisPresley',
#   'ChuckBerry',
#   'TheJackson5',
#   'KylieMinogue',
#   'PerryComoTheFontaneSisters',
#   'DarleneLove',
#   'EltonJohn',
#   'JonasEsticado',
#   'DarylHallJohnOates',
#   'BritneySpears',
#   'BrettEldredge',
#   'JonasBrothers',
#   'GwenStefani',
#   'IdinaMenzel',
#   'EarthaKittHenriReneHisOrchestra',
#   'MykolaDmytrovychLeontovychJohnWilliams',
#   'StevieWonder',
#   'BruceSpringsteen',
#   'LeonaLewis',
#   'TheBeachBoys',
#   'LiamPayne',
#   'MeghanTrainor',
#   'BingCrosby',
#   'Pentatonix',
#   'DonnyHathaway',
#   'TonyBennett',
#   'KatyPerry',
#   'NSYNC',
#   'Eagles',
#   'ToryLanezJackHarlow',
#   'salemilese',
#   'BadBunnyJowellRandyengoFlow',
#   'StudioKillers',
#   'BadBunnyABRA',
#   'TrioVegabajeo',
#   'JhayCortezBadBunny',
#   'SferaEbbasta',
#   'CleanBanditMabel',
#   'ChristianNodalngelaAguilar',
#   'MasterKG',
#   'Tainy',
#   'AyaNakamura',
#   'JustinTimberlake',
#   '21SavageMetroBoomin',
#   'Wallows',
#   'DanShay',
#   'Vedo',
#   'ManuelTurizo',
#   'StaySolidRocky',
#   'FutureLilUziVert',
#   'KaneBrown',
#   'KDAMadisonBeerGIDLELexieLiuJairaBurnsSeraphineLeagueofLegends',
#   'OctavianSkepta',
#   'TyDollaign',
#   'LittleMix',
#   'MAX',
#   'NellyFurtadoTimbaland',
#   'Labrinth',
#   'AnuelAABadBunny',
#   'Kina',
#   'DDG',
#   'LukeCombs',
#   'SuperYeiJoneQuest',
#   'Joji',
#   'DaddyYankeeAnuelAAKendoKaponi',
#   'CaliYElDandeeDannaPaola',
#   'KHEA',
#   'OzunaKAROLGMykeTowers',
#   'MichaelJackson',
#   'BonezMC',
#   'ACDC',
#   'MoneyMan',
#   'BigSean',
#   'BlackEyedPeasOzunaJReySoul',
#   'LauvConanGray',
#   'MarshmelloDemiLovato',
#   'THESCOTTSTravisScottKidCudi',
#   'TruenoBizarrapTaiuTATOOL',
#   'Passenger',
#   'MelanieMartinez',
#   'KygoOneRepublic',
#   'Adele',
#   'AliGatie',
#   'CurtisWaters',
#   'GEazy',
#   '13OrganisSCHKofsJulNapsSosoManessElamsSoldaHouari',
#   'BebeRexha',
#   'ROSALA',
#   'Gunna',
#   'RauwAlejandroDalexLennyTavrez',
#   'NoahCyrus',
#   'BENEEGusDapperton',
#   'Niack',
#   'FeidJBalvinJustinQuiles',
#   'ChrisBrown',
#   'BrysonTiller',
#   'WhoHeem',
#   'JojiDiplo',
#   'BeaMiller',
#   'JojiBENEE',
#   'Dalex',
#   'JuiceWRLDPoloG',
#   'HarryNach',
#   'KendrickLamarJayRock',
#   'InternetMoneyDiplo',
#   'EarthWindFire',
#   'RegardRAYE',
#   'DamsoHamza',
#   'Damso',
#   '6ix9ine',
#   'KygoDonnaSummer',
#   'OzunaDojaCatSia',
#   'SZATheNeptunesPharrellWilliamsTyDollaign',
#   'Matu',
#   'AlexRoseRafaPabn',
#   'BonezMCMaxwell',
#   'HeadieOne',
#   'Nea',
#   'BeyoncMeganTheeStallion',
#   'RobinSchulzWes',
#   'KDAGIDLEWolftylaBeaMillerLeagueofLegends',
#   'McZaacAnittaTyga',
#   'PeachTreeRascals',
#   'BlackEyedPeasJBalvin',
#   'KitschKriegJamuleSFR',
#   'KygoTinaTurner',
#   'Conkarah',
#   'Cordae',
#   'JACKBOYSTravisScott',
#   'JowellRandyJBalvin',
#   'AnuelAA',
#   'JustinQuilesDaddyYankeeElAlfa',
#   'InternetMoneyGunnaDonToliverNAV',
#   'CapitalBraCro',
#   'FeidJustinQuiles',
#   'BausaJuju',
#   'Mustard',
#   'JasonMraz',
#   '5SecondsofSummer',
#   'S1mba',
#   'HeadieOneDrake',
#   'RauwAlejandroChenchoCorleone',
#   'JasonDeruloPuriJhorrmountain',
#   'twocolors',
#   'KygoWhitneyHouston',
#   'Juanfran',
#   'NLEChoppa',
#   'VIZETomGregory',
#   'AAPFerg',
#   'ElAlfaChaelProduciendo',
#   'CapitalBraCluesoKCRebell',
#   'OneDirection',
#   'Ufo361Sonus030',
#   'DripReport',
#   'Logic',
#   'StaySolidRockyLilUziVert',
#   'TrevorDaniel',
#   'Luciano',
#   'LilNasXBillyRayCyrus',
#   'AnuelAADaddyYankeeKAROLGOzunaJBalvin',
#   'DalexLennyTavrezChenchoCorleoneJuhnDmeloFlow',
#   'BadBunnySech',
#   'DmeloFlowArcangelSech',
#   'KontraK',
#   'KanyeWestTravisScott',
#   'RedVelvetIRENESEULGI',
#   'SamFischer',
#   'Y2Kbbno',
#   'SleepyHallowFoushe',
#   'TylaYaweh',
#   'ianndior',
#   'JhayCortezJBalvinBadBunny',
#   'RauwAlejandroChenchoCorleoneKEVVOBryantMyersLyannoDalex',
#   'Journey',
#   'Beyonc',
#   'MiksuMacloudSummerCemLucianoJamule',
#   'LilUziVert',
#   'Lauv',
#   'PanicAtTheDisco',
#   'BoomdabashAlessandraAmoroso',
#   'KhalidDisclosure',
#   'BadBunnyDonOmar',
#   'Tyga',
#   'CapitalBraBozza',
#   'ABoogieWitdaHoodie',
#   'Bosh',
#   'AlidaRobinSchulz',
#   'Alexander23',
#   'MEDUZAGoodboys',
#   'BadBunnyDaddyYankee',
#   'PUBLIC',
#   'PopSmokeRowdyRebel',
#   'Shablo',
#   'Ufo361CLINE',
#   'NatalieTaylor',
#   'NAV',
#   'KygoZaraLarssonTyga',
#   'AlecBenjamin',
#   'PARTYNEXTDOORRihanna',
#   'KCRebellSummerCem',
#   'ChildishGambino',
#   'RauwAlejandroFarruko',
#   'BadBunnyNickyJam',
#   'BadBunnyTainy',
#   'YNWMelly',
#   'KygoKimPetras',
#   'AKAUSSERKONTROLLEBonezMC',
#   'KALIMUfo361',
#   'LilYachty',
#   'KygoZakAbel',
#   'AgustD',
#   'CapitalBra',
#   'YandelBadBunny',
#   'BadBunnyZionLennox',
#   'IU',
#   'VicetoneTonyIgy',
#   'ArcangelSechRomeoSantos',
#   'jxdn',
#   'SechDaddyYankee',
#   'NickyJamDaddyYankee',
#   'PoloGStunna4VegasNLEChoppaMikeWiLLMadeIt',
#   'GHerboJuiceWRLDLilUziVertChancetheRapper',
#   'TrippieReddPARTYNEXTDOOR',
#   'KinaAdrianaProenza',
#   'BadBunnyGabriela',
#   'BandaMSdeSergioLizrragaSnoopDogg',
#   'CapitalBraLoredana',
#   'Ashe',
#   'Kehlani',
#   'FutureDrakeYoungThug',
#   'NAVGunna',
#   'Ufo361',
#   'ToryLanez',
#   'RauwAlejandroAnuelAANattiNatashaFarrukoLunay',
#   'BROCKHAMPTON',
#   'ShakiraAnuelAA',
#   'The1975',
#   'AlanWalkerAvaMax',
#   'CamiloPedroCap',
#   'EllieGoulding',
#   'RvssianAnuelAAJuiceWRLD',
#   'KygoSashaAlexSloan',
#   'KAROLGAnuelAA',
#   'DominicFike',
#   'Samra',
#   'TheChainsmokersILLENIUMLennonStella',
#   'LunayMykeTowersOzunaChenchoCorleoneRauwAlejandro',
#   'PoloGStunna4Vegas',
#   'SubUrban',
#   'Lizzo',
#   'Bazzi',
#   'ShivaEiffel65',
#   'ZunaLoredanaSRNO',
#   'BadBunnyYaviah',
#   'JhayCortezAnuelAAJBalvin',
#   'JBalvinSkyRompiendo',
#   'NiallHoran',
#   'JBalvinMrEazi',
#   'DardanMonet192',
#   'ChristianNodal',
#   'JhenAiko',
#   'BadBunnyAnuelAA',
#   'LilUziVert21Savage',
#   'BadBunnyDukiPabloChillE',
#   'Ninho',
#   'BadBunnyengoFlow',
#   'BadBunnyMora',
#   'SZAJustinTimberlake',
#   'NickyJamAnuelAA',
#   'HenriqueJuliano',
#   'Residente',
#   'BadBunnyKendoKaponiArcangel',
#   'LauvTroyeSivan',
#   'BadBunnyMykeTowers',
#   'DaddyYankeeSech',
#   'LunayOzunaAnuelAA',
#   'LauvLANY',
#   'DalexLennyTavrezAnittaNattiNatashaFarrukoJustinQuiles',
#   'ArcangelBadBunny',
#   'TOKYOSREVENGE',
#   'Stormzy',
#   'CapitalBraSamra',
#   'RichMusicLTDSechDalexJustinQuilesLennyTavrezFeidWisinZion',
#   'LunayDaddyYankeeBadBunny',
#   'SHAED',
#   'ThiaguinhoMTMilaJSoModeOuro',
#   'RichMusicLTDSechDalexJustinQuilesLennyTavrezFeid',
#   'PEDROSAMPAIOFelipeOriginalJSoModeOuro',
#   'KCAMP',
#   'SechOzuna',
#   'MajorLazerDiplo',
#   'ReikJBalvinLaloEbratt',
#   'DalexSech',
#   'MigosTravisScottYoungThug',
#   'KygoSandroCavazza',
#   'JokerBraVIZE',
#   'MacMiller',
#   'JustinBieberQuavo',
#   'AntSaunders',
#   'AnneMarie',
#   'LilWayne',
#   'JustinBieberKehlani',
#   'ROSALAOzuna',
#   'JustinQuilesNattiNatashaFarruko',
#   'Piso21ChristianNodal',
#   'DJSnakeJBalvin',
#   'RedVelvet',
#   'ROSALAJBalvinElGuincho',
#   'TravisScottYoungThug',
#   'DaddyYankeeSnow',
#   'SechOzunaAnuelAADarellNickyJam',
#   'MatthewWilder',
#   'JujuLoredanaMiksuMacloud',
#   'RitonOliverHeldens',
#   'Shakira',
#   'MeekMill',
#   'JColeYoungThug',
#   'Gzuz',
#   'SamraELIF',
#   'MurdaEzhel',
#   'SamFeldt',
#   'Ufo361Future',
#   'Gambi',
#   'MaesBooba',
#   'IdinaMenzelAURORA',
#   'Mabel',
#   'TrippieReddDaBaby',
#   'PedroCapFarruko',
#   'TheChainsmokersKygo',
#   'JACKBOYSSheckWes',
#   'FrenchMontana',
#   'SHAEDZAYN',
#   'JACKBOYSPopSmokeTravisScott',
#   'JACKBOYS',
#   'AnittaLexaLusaSonza',
#   'GradurHeussLenfoir',
#   'DadBoladoTatiZaquiOIK'],
#  'Total Streams': [86402001,
#   99132817,
#   163685977,
#   80580568,
#   84129024,
#   133496415,
#   52301649,
#   203813133,
#   110204230,
#   22405111,
#   238400020,
#   225842427,
#   149088439,
#   17617965,
#   16606925,
#   15089184,
#   20064851,
#   62962128,
#   14273637,
#   14174752,
#   13963568,
#   27136522,
#   12572307,
#   32082208,
#   67718896,
#   11629418,
#   11553846,
#   11524288,
#   11477024,
#   11283626,
#   10739770,
#   10315460,
#   25117823,
#   10215216,
#   10032746,
#   9841998,
#   9799701,
#   9781153,
#   97575714,
#   9600707,
#   14218921,
#   9319465,
#   15219205,
#   9086979,
#   30664296,
#   14664924,
#   33146169,
#   8935418,
#   8832945,
#   8564775,
#   14578460,
#   34050420,
#   19864465,
#   8269753,
#   8133401,
#   8102107,
#   8093413,
#   8006336,
#   7912399,
#   7735223,
#   7717211,
#   22001919,
#   128538281,
#   12863554,
#   7452633,
#   7434252,
#   7383369,
#   7381585,
#   7365053,
#   7353795,
#   7336542,
#   133298543,
#   7084292,
#   7064003,
#   6984262,
#   6853994,
#   11775738,
#   11466205,
#   6709106,
#   21416659,
#   17357932,
#   16649901,
#   6653690,
#   17571933,
#   6614072,
#   6584896,
#   6546948,
#   6539852,
#   15950399,
#   6469500,
#   6317487,
#   6244011,
#   6242863,
#   76392587,
#   11209724,
#   6152121,
#   11743625,
#   6089242,
#   6065267,
#   5952490,
#   5914661,
#   5912784,
#   5907750,
#   5848466,
#   10854432,
#   11231424,
#   21492335,
#   26102099,
#   5734402,
#   5693848,
#   46095750,
#   5690260,
#   5682062,
#   5672480,
#   5668576,
#   5652272,
#   21226750,
#   5627257,
#   5618268,
#   5594505,
#   5576844,
#   173634217,
#   5566150,
#   166703004,
#   5467753,
#   5434073,
#   5382191,
#   5379704,
#   5378971,
#   10457226,
#   5366242,
#   5238547,
#   5235335,
#   5178490,
#   5145493,
#   5145432,
#   5103014,
#   15427499,
#   5065132,
#   5063181,
#   4992405,
#   4978559,
#   4977498,
#   9426756,
#   24929200,
#   162935796,
#   6464206,
#   21983251,
#   112153087,
#   9980286,
#   5383125,
#   5288927,
#   5242097,
#   5235088,
#   11613026,
#   5116589,
#   96534859,
#   5454994,
#   5269757,
#   14356552,
#   5186354,
#   5173178,
#   5068677,
#   5041120,
#   5036030,
#   4954679,
#   9840917,
#   6731106,
#   5876058,
#   29923541,
#   5258628,
#   5234112,
#   10780759,
#   5013017,
#   5011753,
#   32573538,
#   10157380,
#   4980155,
#   4973063,
#   4965913,
#   9914991,
#   34872400,
#   5341887,
#   5203364,
#   10104153,
#   6893939,
#   6308369,
#   5666770,
#   5511544,
#   139225252,
#   34671303,
#   5124606,
#   5085147,
#   32431754,
#   15295764,
#   4911162,
#   4910070,
#   4862683,
#   4846549,
#   33044554,
#   5395181,
#   5155238,
#   98918762,
#   13574034,
#   6040553,
#   15450149,
#   20617331,
#   5300884,
#   10546576,
#   10144244,
#   5378350,
#   5207186,
#   10343558,
#   5068972,
#   5051514,
#   6935400,
#   27579581,
#   12861124,
#   6277641,
#   6237019,
#   15104078,
#   5282702,
#   5252767,
#   5174437,
#   15650087,
#   5156496,
#   5152139,
#   5595839,
#   5518444,
#   5375782,
#   15580809,
#   5218146,
#   10652746,
#   5127736,
#   5831357,
#   26834648,
#   5290877,
#   5258000,
#   27088319,
#   5203700,
#   5103863,
#   5088848,
#   9541089,
#   14794012,
#   5018005,
#   7939784,
#   10683248,
#   11083517,
#   381480455,
#   5377794,
#   16486120,
#   5198209,
#   5026961,
#   5531998,
#   5496962,
#   5181180,
#   5141640,
#   30437725,
#   4998044,
#   14737654,
#   4940701,
#   5380517,
#   9974550,
#   10100801,
#   14626871,
#   5217052,
#   5206614,
#   5172999,
#   5413003,
#   5269163,
#   5176493,
#   5086382,
#   5078174,
#   5060336,
#   5052717,
#   19849326,
#   4969662,
#   4967348,
#   19902243,
#   50589690,
#   5510113,
#   5466954,
#   5410730,
#   5356696,
#   5326719,
#   10382142,
#   5211351,
#   15880847,
#   5528508,
#   5312876,
#   19931860,
#   5098581,
#   10228836,
#   10837487,
#   19791388,
#   5198514,
#   5156937,
#   28524406,
#   5054881,
#   5052557,
#   46346067,
#   5013851,
#   5510906,
#   5321946,
#   11161884,
#   5208787,
#   56018346,
#   5168240,
#   5093408,
#   5073657,
#   5060903,
#   5874460,
#   11475238,
#   5079580,
#   21873859,
#   4982892,
#   5936752,
#   5897983,
#   5497942,
#   5116325,
#   5059891,
#   5004462,
#   5232509,
#   5163323,
#   5044252,
#   4908929,
#   5579697,
#   9740646,
#   9638133,
#   5046418,
#   4900492,
#   4873380,
#   5487774,
#   5136895,
#   10005180,
#   35692921,
#   4942545,
#   5427534,
#   48290899,
#   4914093,
#   4864544,
#   4833081,
#   5942551,
#   5119828,
#   4983557,
#   4915403,
#   9333245,
#   5622565,
#   4906324,
#   4769618,
#   37058291,
#   4858392,
#   4848222,
#   4655272,
#   4580123,
#   81957273,
#   4516053,
#   4488125,
#   30405426,
#   20709328,
#   16613649,
#   16527404,
#   33454625,
#   14582001,
#   12266990,
#   11664490,
#   25479949,
#   25194507,
#   10508459,
#   10476212,
#   19507860,
#   9509781,
#   8804531,
#   16866417,
#   7045348,
#   11332458,
#   6716353,
#   6404964,
#   6052105,
#   6007011,
#   5802508,
#   13866000,
#   5687085,
#   5422082,
#   5394054,
#   5353591,
#   5191001,
#   10522305,
#   9457199,
#   9270017,
#   28044285,
#   8696354,
#   8160534,
#   8022773,
#   7993078,
#   7792643,
#   7363913,
#   7350024,
#   7301381,
#   7299201,
#   13560766,
#   7149158,
#   6985392,
#   6809438,
#   6680928,
#   21477139,
#   6635128,
#   6400108,
#   6567755,
#   5436450,
#   5390363,
#   5364223,
#   11066606,
#   5842320,
#   5463964,
#   22965495,
#   6241923,
#   6152821,
#   5362508,
#   10144660,
#   9652860,
#   4988571,
#   73502663,
#   4911995,
#   4911749,
#   4907925,
#   4899440,
#   4878286,
#   23422826,
#   5929062,
#   5602168,
#   5361669,
#   9886621,
#   9794665,
#   5158896,
#   5083648,
#   4926802,
#   4899099,
#   4872409,
#   4863053,
#   4746415,
#   4739241,
#   46558205,
#   4731423,
#   4713873,
#   5220504,
#   5033798,
#   5605234,
#   32394159,
#   5096618,
#   4904772,
#   11496272,
#   5016343,
#   5010179,
#   4980744,
#   4941592,
#   4817969,
#   4765198,
#   4745568,
#   4709053,
#   4703672,
#   9909303,
#   5183246,
#   9415493,
#   5112572,
#   4870203,
#   4752289,
#   28718955,
#   4607003,
#   4598766,
#   5089970,
#   9147693,
#   4727923,
#   4641393,
#   7762934,
#   5109038,
#   6819838,
#   5463424,
#   4977405,
#   4964708,
#   4851997,
#   4761286,
#   4632724,
#   4628159,
#   5329256,
#   5178107,
#   5101640,
#   5094137,
#   18746162,
#   4569978,
#   5698099,
#   5049863,
#   4938139,
#   4877753,
#   4723116,
#   4602336,
#   4598325,
#   4568308,
#   4668193,
#   4642057,
#   4615520,
#   4593366,
#   4585895,
#   4572706,
#   4538382,
#   4624448,
#   4609169,
#   10183352,
#   4575403,
#   23479962,
#   4501441,
#   11373347,
#   5440253,
#   4702117,
#   4685894,
#   4436934,
#   4391666,
#   25313094,
#   4488631,
#   4480780,
#   4466143,
#   4462411,
#   4439790,
#   4392936,
#   4380308,
#   13713356,
#   4522005,
#   5768616,
#   4661170,
#   5600868,
#   9595200,
#   4823401,
#   4669248,
#   4621205,
#   15129295,
#   5228433,
#   11144212,
#   4643817,
#   4627026,
#   4617726,
#   4613982,
#   4485060,
#   5867111,
#   5586085,
#   5030481,
#   4597406,
#   4541965,
#   5280810,
#   5031845,
#   4571916,
#   4501188,
#   4433384,
#   4394985,
#   5474807,
#   5415994,
#   208822039,
#   25539351,
#   4426791,
#   4374448,
#   4374392,
#   4312675,
#   11930392,
#   5827600,
#   22009197,
#   4924714,
#   4654587,
#   4473413,
#   4422905,
#   4384527,
#   4356213,
#   6042929,
#   5171235,
#   5113459,
#   4627942,
#   4623279,
#   4463865,
#   4393932,
#   4361970,
#   9710912,
#   4727415,
#   4432324,
#   4432210,
#   4350496,
#   13397967,
#   5867930,
#   5494500,
#   4629320,
#   13818747,
#   4573723,
#   8908179,
#   5552890,
#   5132247,
#   4987116,
#   4764954,
#   4642284,
#   4440738,
#   4435538,
#   4419295,
#   4407165,
#   5464816,
#   4500903,
#   4416484,
#   4397385,
#   5364262,
#   4971559,
#   4912914,
#   4609358,
#   4603243,
#   10537097,
#   5594561,
#   19712998,
#   14735472,
#   4401019,
#   4362442,
#   4440661,
#   4429092,
#   4395061,
#   4393037,
#   4367368,
#   4822090,
#   4674532,
#   4593449,
#   4411998,
#   15937577,
#   4359727,
#   4261965,
#   4244510,
#   4218201,
#   15266767,
#   9863274,
#   5995116,
#   5878493,
#   4946613,
#   4901559,
#   5745393,
#   16017110,
#   5044774,
#   4701388,
#   4591194,
#   4557817,
#   4438261,
#   8374259,
#   6105711,
#   5895243,
#   5544180,
#   5411302,
#   5193927,
#   5130783,
#   11173517,
#   7240117,
#   6041127,
#   5547770,
#   5359969,
#   5325447,
#   5206102,
#   5110064,
#   5676621,
#   5490386,
#   5286044,
#   5273046,
#   5192813,
#   5112244,
#   5078459,
#   5075520,
#   5510844,
#   5135469,
#   5013019,
#   4994448,
#   4954292,
#   4950254,
#   4897374,
#   4851895,
#   9652399,
#   5421905,
#   5376451,
#   83342862,
#   28509534,
#   6554824,
#   11038970,
#   5561205,
#   5236560,
#   5202210,
#   5148516,
#   5066711,
#   5013732,
#   4991751,
#   4961249,
#   4905155,
#   4861378,
#   4803294,
#   5312936,
#   5208651,
#   4925843,
#   4918636,
#   4889500,
#   4791732,
#   6113037,
#   5297101,
#   5037967,
#   4855270,
#   6010373,
#   5678754,
#   5656775,
#   5705999,
#   4931458,
#   4929396,
#   4879713,
#   6145132,
#   5898484,
#   5229616,
#   8896030,
#   7685470,
#   5363493,
#   5149797,
#   4676857,
#   4607385]}

# %%
# Create a visualization for the total streams for each artist
sns.set_theme(style="whitegrid")
sns.set(rc={'figure.figsize':(9,6)})
dictionary = total_streams()
spotify_pop = pd.DataFrame(dictionary)
spotify_pop.sort_values(by=['Total Streams'], ascending=False, inplace=True)
print(spotify_pop)

sns.barplot(x="Artist", y="Total Streams", data=spotify_pop[:10], palette="rocket")

plt.xticks(rotation = 70) # rotate the labels

plt.show()

### CITATION: https://seaborn.pydata.org/generated/seaborn.barplot.html
# Out:
#                                                Artist  Total Streams
# 248                                       TaylorSwift      381480455
# 10                                                BTS      238400020
# 11                                       JustinBieber      225842427
# 555                                        LilUziVert      208822039
# 7                                            BadBunny      203813133
# ..                                                ...            ...
# 582                                     BadBunnyTainy        4350496
# 560                                   BadBunnyDonOmar        4312675
# 625  LunayMykeTowersOzunaChenchoCorleoneRauwAlejandro        4261965
# 626                                 PoloGStunna4Vegas        4244510
# 627                                          SubUrban        4218201
#
# [716 rows x 2 columns]

# %% [markdown]
# ## Genre Visualizations

# %%
genres = spotify["Genre"]
unique_genres = [None]* 334
count = 0
for i in range(len(genres)):
    genre = genres[i].split(",")
    for j in range(len(genre)):
        if genre[j].replace('[', ' ').replace(']', ' ').replace("'", ' ').strip() not in unique_genres:
            if genre[j].replace('[', ' ').replace(']', ' ').replace("'", ' ').strip() != '':
                unique_genres[count] = genre[j].replace('[', ' ').replace(']', ' ').replace("'", ' ').strip()
                count = count + 1

# %%
# Take a look at the genres
print(unique_genres)
# Out:
# ['indie rock italiano', 'italian pop', 'australian hip hop', 'pop', 'uk pop', 'lgbtq+ hip hop', 'pop rap', 'dance pop', 'puerto rican pop', 'trap latino', 'latin', 'reggaeton', 'reggaeton colombiano', 'k-pop', 'k-pop boy group', 'canadian pop', 'post-teen pop', 'canadian contemporary r&b', 'gauze pop', 'indietronica', 'shiver pop', 'latin hip hop', 'dfw rap', 'melodic rap', 'rap', 'house', 'pop dance', 'tropical house', 'uk dance', 'electropop', 'colombian pop', 'chicago rap', 'panamanian pop', 'latin pop', 'pop argentino', 'big room', 'brostep', 'dutch edm', 'edm', 'electro house', 'slap house', 'trance', 'cali rap', 'trap argentino', 'argentine hip hop', 'pop venezolano', 'progressive electro house', 'dreamo', 'indie surf', 'surf punk', 'vegas indie', 'pop rock', 'piano rock', 'houston rap', 'trap queen', 'german dance', 'german techno', 'german trance', 'r&b', 'modern alternative rock', 'modern rock', 'canadian hip hop', 'toronto rap', 'brooklyn drill', 'nyc rap', 'aussietronica', 'mexican hip hop', 'rap conciencia', 'australian pop', 'hip hop', 'comic', 'melanesian pop', 'pacific islands pop', 'png pop', 'canadian trap', 'southern hip hop', 'trap', 'trap soul', 'underground hip hop', 'dutch pop', 'german hip hop', 'rap latina', 'afrofuturism', 'uk hip hop', 'alt z', 'rock', 'latin viral pop', 'chill r&b', 'nyc pop', 'progressive house', 'sertanejo', 'sertanejo pop', 'sertanejo universitario', 'viral pop', 'north carolina hip hop', 'bedroom pop', 'indie pop', 'folk-pop', 'grunge', 'permanent wave', 'pop soul', 'irish singer-songwriter', 'classic rock', 'glam rock', 'pop house', 'new french touch', 'plugg', 'vapor trap', 'viral rap', 'forro', 'art pop', 'norwegian pop', 'dance rock', 'album rock', 'art rock', 'mellow gold', 'new wave', 'soft rock', 'yacht rock', 'talent show', 'urban contemporary', 'sad rap', 'contemporary country', 'country', 'country road', 'modern country rock', 'neo soul', 'funk bh', 'funk carioca', 'pop edm', 'pop nacional', 'detroit hip hop', 'german alternative rap', 'german drill', 'german trap', 'london rap', 'italian hip hop', 'neo mellow', 'singer-songwriter', 'funk ostentacao', 'funk paulista', 'queens hip hop', 'sudanese pop', 'k-pop girl group', 'escape room', 'reggaeton flow', 'rave funk', 'beatlesque', 'britpop', 'madchester', 'dmv rap', 'eau claire indie', 'folktronica', 'miami hip hop', 'metropopolis', 'nz pop', 'frauenrap', 'german pop', 'garage rock', 'sheffield indie', 'atl hip hop', 'italian adult pop', 'francoton', 'french hip hop', 'pop urbaine', 'rap francais', 'rap marseille', 'conscious hip hop', 'emo rap', 'seattle hip hop', 'ohio hip hop', 'dembow', 'dominican pop', 'rap dominicano', 'alternative metal', 'nu metal', 'post-grunge', 'rap metal', 'funk 150 bpm', 'atl trap', 'rap conscient', 'eurovision', 'nouvelle chanson francaise', 'hip pop', 'oulu metal', 'trancecore', 'boston hip hop', 'bubblegrunge', 'chicago indie', 'dream smp', 'icelandic pop', 'sunnlensk tonlist', 'uk alternative pop', 'indie cafe pop', 'bedroom soul', 'hamburg hip hop', 'weirdcore', 'funk pop', 'pagode baiano', 'memphis hip hop', 'tennessee hip hop', 'alternative r&b', 'piseiro', 'east coast hip hop', 'gangster rap', 'hardcore hip hop', 'trap triste', 'vancouver indie', 'deep underground hip hop', 'kentucky hip hop', 'new romantic', 'new wave pop', 'synthpop', 'electronic trap', 'australian dance', 'deep euro house', 'deep house', 'australian psych', 'neo-psychedelic', 'indie poptimism', 'indonesian pop', 'italian indie pop', 'italian pop rock', 'trap boricua', 'old school rap francais', 'urbano espanol', 'rhode island rap', 'etherpop', 'modern indie pop', 'social media pop', 'melodic metalcore', 'metalcore', 'uk metalcore', 'brazilian hip hop', 'cubaton', 'tekk', 'cumbia pop', 'disco', 'europop', 'adult standards', 'brill building pop', 'easy listening', 'lounge', 'rockabilly', 'vocal jazz', 'jazz pop', 'musical advocacy', 'folk rock', 'soul', 'swing', 'american folk revival', 'celtic', 'celtic punk', 'cel ...

# %%
# Seperate into more general genres
pop = spotify[spotify['Genre'].str.contains('pop')]
indie = spotify[spotify['Genre'].str.contains('indie')]
Rap = spotify[spotify['Genre'].str.contains('rap')]
country = spotify[spotify['Genre'].str.contains('country')]
rock = spotify[spotify['Genre'].str.contains('rock')]
rb = spotify[spotify['Genre'].str.contains('r&b')]
folk = spotify[spotify['Genre'].str.contains('folk')]
soul = spotify[spotify['Genre'].str.contains('soul')]
edm = spotify[spotify['Genre'].str.contains('edm')]

# %%
print("Pop song count:",pop['Song Name'].count())
print("Indie song count:",indie['Song Name'].count())
print("Rap song count:",Rap['Song Name'].count())
print("Country song count:",country['Song Name'].count())
print("Rock song count:",rock['Song Name'].count())
print("R&B song count:",rb['Song Name'].count())
print("Folk song count:",folk['Song Name'].count())
print("Soul song count:",soul['Song Name'].count())
print("EDM song count:",edm['Song Name'].count())
# Out:
# Pop song count: 819
# Indie song count: 38
# Rap song count: 654
# Country song count: 14
# Rock song count: 74
# R&B song count: 75
# Folk song count: 7
# Soul song count: 14
# EDM song count: 50

# %%
# Creates Pie chart
count_labels = ['Pop','Indie','Rap','Country','Rock','R&B','Folk','Soul','EDM']
count_totals = [819,38,654,14,74,75,7,14,50]
plt.figure(figsize=(12, 12))
plt.pie(count_totals, labels=count_labels, autopct='%1.0f%%', pctdistance=1.1, labeldistance=1.25)
# Out:
# ([<matplotlib.patches.Wedge at 0x2562c59ce20>,
#   <matplotlib.patches.Wedge at 0x2562c5a8550>,
#   <matplotlib.patches.Wedge at 0x2562c5a8af0>,
#   <matplotlib.patches.Wedge at 0x2562c5b61f0>,
#   <matplotlib.patches.Wedge at 0x2562c5b6880>,
#   <matplotlib.patches.Wedge at 0x2562c5b6f70>,
#   <matplotlib.patches.Wedge at 0x2562c5c2670>,
#   <matplotlib.patches.Wedge at 0x2562c5c2d00>,
#   <matplotlib.patches.Wedge at 0x2562c5ce3d0>],
#  [Text(0.1202116174877519, 1.2442062397452356, 'Pop'),
#   Text(-1.2403677386220968, 0.15488018913181184, 'Indie'),
#   Text(-0.5427890833122413, -1.1260017810985277, 'Rap'),
#   Text(0.8551916208013144, -0.9116727986022294, 'Country'),
#   Text(0.98831413317039, -0.7653333745340396, 'Rock'),
#   Text(1.1558159014618197, -0.47601428752507136, 'R&B'),
#   Text(1.2132618347575177, -0.30082506597825565, 'Folk'),
#   Text(1.2237654566286773, -0.2547510690113089, 'Soul'),
#   Text(1.2449390106720366, -0.11236930055371498, 'EDM')],
#  [Text(0.10578622338922168, 1.0949014909758072, '47%'),
#   Text(-1.0915236099874452, 0.1362945664359944, '2%'),
#   Text(-0.4776543933147724, -0.9908815673667045, '37%'),
#   Text(0.7525686263051568, -0.8022720627699619, '1%'),
#   Text(0.8697164371899433, -0.6734933695899549, '4%'),
#   Text(1.0171179932864014, -0.41889257302206284, '4%'),
#   Text(1.0676704145866156, -0.264726058060865, '0%'),
#   Text(1.0769136018332361, -0.22418094072995184, '1%'),
#   Text(1.0955463293913923, -0.09888498448726919, '3%')])

# %%
# Creates bar chart
plt.figure(figsize=(20, 15))
y_pos = np.arange(len(count_labels))
c = ['red','blue','green','purple','orange','pink','black','yellow','brown']
sns.barplot(y_pos, count_totals)

plt.show()
# Out:
# C:\Users\bobca\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Based on various websites such as https://soundcharts.com/blog/music-streaming-rates-payouts and https://producerhive.com/music-marketing-tips/streaming-royalties-breakdown/
payout = 0.00318
#Strips , in Streams and turns it into a int type. Then finds min to see what is the minimum amount of songs you would need to chart on the Top 200 charts on Spotify.
genre = '"Pop"'
pop = pop.replace(',','', regex=True)
pop['Streams'] = pop['Streams'].astype(int)
popmean = int(pop['Streams'].mean())
poptotal = round(popmean*payout,2)
print("The average amount of streams for the genre",genre,"is",popmean,"streams.")
print("On average the amount made from a song in",genre,"that charts in the top 200 is",poptotal,"dollars")
print("")

genre = '"Indie"'
indie = indie.replace(',','', regex=True)
indie['Streams'] = indie['Streams'].astype(int)
indiemean = int(indie['Streams'].mean())
indietotal = round(indiemean*payout,2)
print("The average amount of streams for the genre",genre,"is",indiemean,"streams.")
print("On average the amount made from a song in",genre,"that charts in the top 200 is",indietotal,"dollars")
print("")


genre = '"Rap"'
Rap = Rap.replace(',','', regex=True)
Rap['Streams'] = Rap['Streams'].astype(int)
Rapmean = int(Rap['Streams'].mean())
Raptotal = round(Rapmean*payout,2)
print("The average amount of streams for the genre",genre,"is",Rapmean,"streams.")
print("On average the amount made from a song in",genre,"that charts in the top 200 is",Raptotal,"dollars")
print("")

genre = '"Country"'
country = country.replace(',','', regex=True)
country['Streams'] = country['Streams'].astype(int)
countrymean = int(country['Streams'].mean())
countrytotal = round(countrymean*payout,2)
print("The average amount of streams for the genre",genre,"is",countrymean,"streams.")
print("On average the amount made from a song in",genre,"that charts in the top 200 is",countrytotal,"dollars")
print("")


genre = '"Rock"'
rock= rock.replace(',','', regex=True)
rock['Streams'] = rock['Streams'].astype(int)
rockmean = int(rock['Streams'].mean())
rocktotal = round(rockmean*payout,2)
print("The average amount of streams for the genre",genre,"is",rockmean,"streams.")
print("On average the amount made from a song in",genre,"that charts in the top 200 is",rocktotal,"dollars")
print("")

genre = '"R&B"'
rb = rb.replace(',','', regex=True)
rb['Streams'] = rb['Streams'].astype(int)
rbmean = int(rb['Streams'].mean())
rbtotal = round(rbmean*payout,2)
print("The average amount of streams for the genre",genre,"is",rbmean,"streams.")
print("On average the amount made from a song in",genre,"that charts in the top 200 is",rbtotal,"dollars")
print("")

genre = '"Folk"'
folk = folk.replace(',','', regex=True)
folk['Streams'] = folk['Streams'].astype(int)
folkmean = int(folk['Streams'].mean())
folktotal = round(folkmean*payout,2)
print("The average amount of streams for the genre",genre,"is",folkmean,"streams.")
print("On average the amount made from a song in",genre,"that charts in the top 200 is",folktotal,"dollars")
print("")

genre = '"Soul"'
soul = soul.replace(',','', regex=True)
soul['Streams'] = soul['Streams'].astype(int)
soulmean = int(soul['Streams'].mean())
soultotal = round(soulmean*payout,2)
print("The average amount of streams for the genre",genre,"is",soulmean,"streams.")
print("On average the amount made from a song in",genre,"that charts in the top 200 is",soultotal,"dollars")
print("")

genre = '"EDM"'
edm = edm.replace(',','', regex=True)
edm['Streams'] = edm['Streams'].astype(int)
edmmean = int(edm['Streams'].mean())
edmtotal = round(edmmean*payout,2)
print("The average amount of streams for the genre",genre,"is",edmmean,"streams.")
print("On average the amount made from a song in",genre,"that charts in the top 200 is",edmtotal,"dollars")
# Out:
# The average amount of streams for the genre "Pop" is 6521754 streams.
# On average the amount made from a song in "Pop" that charts in the top 200 is 20739.18 dollars
#
# The average amount of streams for the genre "Indie" is 7166032 streams.
# On average the amount made from a song in "Indie" that charts in the top 200 is 22787.98 dollars
#
# The average amount of streams for the genre "Rap" is 6097230 streams.
# On average the amount made from a song in "Rap" that charts in the top 200 is 19389.19 dollars
#
# The average amount of streams for the genre "Country" is 5519205 streams.
# On average the amount made from a song in "Country" that charts in the top 200 is 17551.07 dollars
#
# The average amount of streams for the genre "Rock" is 7095281 streams.
# On average the amount made from a song in "Rock" that charts in the top 200 is 22562.99 dollars
#
# The average amount of streams for the genre "R&B" is 6142933 streams.
# On average the amount made from a song in "R&B" that charts in the top 200 is 19534.53 dollars
#
# The average amount of streams for the genre "Folk" is 6537386 streams.
# On average the amount made from a song in "Folk" that charts in the top 200 is 20788.89 dollars
#
# The average amount of streams for the genre "Soul" is 6051740 streams.
# On average the amount made from a song in "Soul" that charts in the top 200 is 19244.53 dollars
#
# The average amount of streams for the genre "EDM" is 5427220 streams.
# On average the amount made from a song in "EDM" that charts in the top 200 is 17258.56 dollars

# %%
# Creates labels and totals
genres = ['Pop', "Indie",'Rap', 'Country','Rock', 'R&B', 'Folk', 'Soul', 'EDM']
totals = [20739.18, 22787.98, 19389.19, 17551.07, 22562.99, 19534.53, 20788.89, 19244.53, 17258.56]
y_pos = np.arange(len(genres))
    
# Creates a line graph
fig, ax = plt.subplots()
ax.plot(genres, totals, label="Genre")
plt.tick_params(axis='x', which='major', labelsize=8)
plt.ylabel('Amount Paid Out')
plt.title("Average Paid By Genre")
ax.legend()
plt.show()

# %%
# Strip commas from streams and turn column into in
spotify = spotify.replace(',','', regex=True)
spotify['Streams'] = spotify['Streams'].astype(int)

# %%
spotify[spotify['Streams'] == spotify['Streams'].max()]
# Out:
#    Index  Highest Charting Position  Number of Times Charted  \
# 0      1                          1                        8
#
#   Week of Highest Charting Song Name   Streams    Artist Artist Followers  \
# 0   2021-07-23--2021-07-30   Beggin'  48633449  Måneskin          3377762
#
#                   Song ID                                  Genre  ...  \
# 0  3Wrjm47oTz2sjIgck11l5e  ['indie rock italiano' 'italian pop']  ...
#
#   Danceability Energy Loudness Speechiness Acousticness Liveness    Tempo  \
# 0        0.714    0.8   -4.808      0.0504        0.127    0.359  134.002
#
#   Duration (ms) Valence Chord
# 0        211560   0.589     B
#
# [1 rows x 23 columns]

# %%
spotify[spotify['Streams']==spotify['Streams'].min()]
# Out:
#       Index  Highest Charting Position  Number of Times Charted  \
# 1250   1251                        117                        8
#
#      Week of Highest Charting                           Song Name  Streams  \
# 1250   2020-02-14--2020-02-21  Good as Hell (feat. Ariana Grande)  4176083
#
#      Artist Artist Followers                 Song ID  \
# 1250  Lizzo          3991674  07Oz5StQ7GRoygNLaXs2pd
#
#                                                   Genre  ... Danceability  \
# 1250  ['dance pop' 'escape room' 'minnesota hip hop'...  ...        0.668
#
#      Energy Loudness Speechiness Acousticness Liveness   Tempo Duration (ms)  \
# 1250  0.892   -3.001      0.0645        0.298    0.735  95.927        159011
#
#      Valence Chord
# 1250   0.478     F
#
# [1 rows x 23 columns]

# %%
# Print out the highest amount made and lowest amount paid out
highestpaid = round(48633449*payout,2)
lowestpaid = round(4176083*payout,2)
print("The amount that was paid out from the highest streaming song 'Beggin' was",highestpaid)
print("The amount that was paid out from the lowest streaming song 'Good as Hell' was",lowestpaid)
# Out:
# The amount that was paid out from the highest streaming song 'Beggin' was 154654.37
# The amount that was paid out from the lowest streaming song 'Good as Hell' was 13279.94
